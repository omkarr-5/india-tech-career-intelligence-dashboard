# %% [markdown]
# # Dashboard Blueprint
#
# ## Page 1 - Market Overview
#
# KPIs:
# - Total Jobs
# - Total Companies
# - Total Skills
# - Total Cities
#
# Charts:
# - Top Roles
# - Top Cities
# - Work Mode Distribution
#
# Business Question:
# What does the Indian tech job market look like?
#
# ## Page 2 - Salary Intelligence
#
# Charts:
#
# - Highest Paying Roles
# - Salary by Experience
# - Salary by City
# - Salary by Company Type
#
# Business Question:
# Where is the money?
#
# ## Page 3 - Skill Intelligence
#
# Charts:
#
# - Top 20 Skills
# - Skills by Role
# - Skills by Experience
#
# Question Answered:
# What should I learn?
#
# ## Page 4 - Career Navigator ⭐
#
# This is the USP.
#
# User selects:
#
# - Data Analyst
# - Data Scientist
# - Software Engineer
# - AI Engineer
# - Data Engineer
#
# Dashboard shows:
#
# - Average Salary
# - Top Skills
# - Top Cities
# - Required Education
# - Openings
#
# Question Answered:
# If I want to become a Data Analyst, what should I know?
